# %% [markdown]
# # Qn 1(a)
# To estimate pi
# \begin{equation}
# \pi \approx  \dfrac{4*counter}{10^6}
# \end{equation}

# %%
#estimate pi using random dots scattered in -1<x<1 and -1<y<1 graph.
import numpy as np
import matplotlib.pyplot as plt
import time

"""
pi is approximated at pi = 4(Number of dots in the circle)/10^6
"""

print ("Computer thinking")
#we produce 2,000,000 because we want to randomize the plots of 2 axis x and y
r = np.random.uniform(-1,1,2000000)
half_length_of_r = len (r)//2 #floor division

x = r[:half_length_of_r]
y = r[half_length_of_r:]

'''
check if len of x and y are same
'''

#print (len(x),len(y))

temp1 = []
counter = 0 #counter for outside the circle
counter2 = 0 #counter for inside of the circle

for i in range(len(x)):
    result = np.sqrt((x[i])**2
                     +(y[i])**2)
    if result < 1:
        counter2 = counter2 +1
        continue #immediately goes to the next loop
    
    else:
        counter = counter + 1
        temp1.append(i)
        continue

print (".")

time.sleep(1.5)
        
'''
Set this new_array to delete the desired values, 
this means this is the values within the circle
'''

new_array1 = np.delete(x, temp1)
new_array2 = np.delete(y, temp1)

plt.plot(new_array1, new_array2, 'o')

print ("The number of points outside the circle is %d."%counter)
time.sleep(1.5)
print ("The number of points INSIDE the circle is %d."%counter2)
time.sleep(1.5)

tally = counter + counter2

if tally == 1000000:
    print ("The total points are %d"%tally)
    time.sleep(1)
    print ("Therefore, the plot tallies")
    time.sleep(1.5)
print("Graph is Loading...")
approx = 4*counter2/10**6
plt.show()

time.sleep(1.5)
print ("")
approx = 4*counter2/10**6
print ("The approximate to pi is %f"%approx)
# Out:
# Computer thinking
# .
# The number of points outside the circle is 214463.
# The number of points INSIDE the circle is 785537.
# The total points are 1000000
# Therefore, the plot tallies
# Graph is Loading...
# The approximate to pi is 3.142148

# %% [markdown]
# # Qn 1(b)
#
# To estimate pi for this question we use
# \begin{equation}
# \pi \approx  \dfrac{8*counter}{10^6}
# \end{equation}
#
# Since now it is in 3 dimensions
# WE produce 3,000,000 because we want to randomize the plots of 2 axis x , y , z respectably

# %%
#estimate pi using random dots scattered in -1<x<1 and -1<y<1 graph.
import numpy as np
import matplotlib.pyplot as plt
import time
from mpl_toolkits.mplot3d import Axes3D
import math

print ("Computer thinking")

r = np.random.uniform(-1,1,3000000)

second_length_of_r = len (r)//3 #floor division
third_length_of_r = second_length_of_r * 2 #2nd iteration for splicing

#print (second_length_of_r,third_length_of_r)

"""
===============================================
Splice and split the random numbers into 
3 to plot random points within the circle 
===============================================

"""
x = r[:second_length_of_r]
y = r[second_length_of_r:third_length_of_r]
z = r[third_length_of_r:]

#print (len (x),len (y),len (z))
temp1 = []
counter = 0 #counter for outside the circle
counter2 = 0 #counter for inside of the circle

"""
===============================================
Use conditional loop to gather those outside 
the circle

COUNTER = POINTS OUTSIDE CIRLE
COUNTER2 = POINTS INSIDE CIRCLE
===============================================

"""
time.sleep(0.5)
print ('.')
for i in range(len(x)):
    result = np.sqrt((x[i])**2+(y[i])**2+(z[i]**2))
    
    if result < 1:
        counter2 = counter2 +1
        continue #immediately goes to the next loop
    
    else:
        counter = counter + 1
        temp1.append(i)
        continue

print ('.')
time.sleep(1)
print ("There are %d inside the circle and %d outside the cirle"%(counter2,counter))
new_array1 = np.delete(x, temp1)
new_array2 = np.delete(y, temp1)
new_array3 = np.delete(z, temp1)

print ("Initializion done")
# Out:
# Computer thinking
# .
# .
# There are 523241 inside the circle and 476759 outside the cirle
# Initializion done

# %% [markdown]
# # Above we initialise gathering counters to obtain which
# # Values are inside or outside the circle and then
# # Gathering the iteration locations then deleting them from
# # The array using np.delete(array,iteration)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
plt.plot(new_array1, new_array2,new_array3, 'o',  mew=0.07, ms=0.12)

tally = counter+counter2
if tally == 1000000:
    print ("There are a total of %d points "%tally)
    time.sleep(1)
    print ("Therefore, the simulation tallies")
    time.sleep(1)

print("Graph is Loading...")
plt.show()

radius = 1.0
time.sleep(1)
Volume_encompassed_by_circle = (8/10**6)*counter2*(radius**3)
Volume_of_CUBE = radius**3
proportionality_constant = Volume_encompassed_by_circle/Volume_of_CUBE
time.sleep(1)
print ("Correct Answer is close to (4/3)*np.pi Hence we shall compare by % error")
time.sleep(1)
EXPECTED_VALUE = (4/3)* np.pi

percentage_error = abs(proportionality_constant-EXPECTED_VALUE)*100
print ("The percentage error is %f. "%percentage_error)
time.sleep(1)
print("therefore we have a good estimation using the above monte carlo model since % error < 1%")
# Out:
# There are a total of 1000000 points
# Therefore, the simulation tallies
# Graph is Loading...
# Correct Answer is close to (4/3)*np.pi Hence we shall compare by % error
# The percentage error is 0.286220.
# therefore we have a good estimation using the above monte carlo model since % error < 1%

# %% [markdown]
# # Here we have proportionality constant as
# \begin{equation}
# \frac{ \frac{4}{3} \ \pi r^3}{r^3} = \frac{4 \pi}{3}
# \end{equation}
#
# # The above simulation shows a correct proportionality constant when we divide
# # Volume_encompassed_by_circle/Volume_of_CUBE

# %% [markdown]
# # Qn 1(c) is a hypersphere
#
# Using the previous methods of creating 4 arrays
# We produce 4,000,000 because we want to randomize the plots of 4 axis
# x , y , z , q respectably where q is the 4th dimension

# %%
#estimate pi using random dots scattered in -1<x<1, -1<y<1, -1<z<1, -1<q<1 graph.
import numpy as np
import matplotlib.pyplot as plt
import time
import math

print ("Computer thinking")

r = np.random.uniform(-1,1,4000000)

second_length_of_r = len (r)//4 #floor division
third_length_of_r = second_length_of_r * 2 #2nd iteration for splicing
fourth_length_of_r = second_length_of_r * 3

#print (second_length_of_r,third_length_of_r)

"""
===============================================
Splice and split the random numbers into 
3 to plot random points within the circle 
===============================================

"""
x = r[:second_length_of_r]
y = r[second_length_of_r:third_length_of_r]
z = r[third_length_of_r:fourth_length_of_r]
q = r[fourth_length_of_r:]

#print (len (x),len (y),len (z))
temp1 = []
counter = 0 #counter for outside the circle
counter2 = 0 #counter for inside of the circle

"""
===============================================
Use conditional loop to gather those outside 
the circle

COUNTER = POINTS OUTSIDE CIRLE
COUNTER2 = POINTS INSIDE CIRCLE
===============================================

"""
time.sleep(0.5)
print ('.')

for i in range(len(x)):
    result = np.sqrt((x[i])**2+(y[i])**2+(z[i]**2)+q[i]**2)
    
    if result < 1:
        counter2 = counter2 +1
        continue #immediately goes to the next loop
    
    else:
        counter = counter + 1
        temp1.append(i)
        continue


print ('.')
time.sleep(0.5)

print ("There are %d inside the circle and %d outside the cirle"%(counter2,counter))

"""
===============================================
Update the new array 
===============================================
"""
new_array1 = np.delete(x, temp1)
new_array2 = np.delete(y, temp1)
new_array3 = np.delete(z, temp1)
new_array4 = np.delete(q, temp1)

tally = counter+counter2
if tally == 1000000:
    time.sleep(1)
    print ("There are a total of %d points "%tally)
    time.sleep(1)
    print ("Therefore, the simulation tallies.")
    time.sleep(1)

#print("Graph is Loading...")
#plt.show()

radius = 1.0
Volume_encompassed_by_circle = (16/10**6)*counter2*(radius**4) #we use 16 from 2**4
Volume_of_CUBE = radius**4
proportionality_constant = Volume_encompassed_by_circle/Volume_of_CUBE
proportionality_constant_in_terms_pi = proportionality_constant/np.pi

print ("In a HyperSphere, the proportionality constant in terms of pi is %f. "%proportionality_constant_in_terms_pi)
# Out:
# Computer thinking
# .
# .
# There are 308304 inside the circle and 691696 outside the cirle
# There are a total of 1000000 points
# Therefore, the simulation tallies.
# In a HyperSphere, the proportionality constant in terms of pi is 1.570179.

# %% [markdown]
# ## From observing the value, it tells us that the proportionality constant (In terms of $\pi$ ) is
#
# \begin{equation}
# C_{proportionality \ constant} = \frac {\pi}{2}
# \end{equation}
#
# Hence, the proportionality constant of the hypersphere is
#
# \begin{equation}
# C_{proportionality \ constant} = \frac {\pi^2}{2}
# \end{equation}

# %% [markdown]
# # Qn 2(a)

# %% [markdown]
# The Poisson Process is the model we use for describing randomly occurring events and by itself, isn’t that useful.
#
# Using the Poisson Distribution, we can find the probability of a number of events in a time period or finding the probability of waiting some time until the next event.
#
# The Poisson Distribution probability mass function gives the probability of observing k events in a time period given the length of the period and the average events per time:
#
# \begin{equation}
# P (k \ events \ in \ interval) = exp ( -\lambda )\frac{\lambda^k}{k!}
# \end{equation}
#
# Lambda is

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


n = random.randint(1,10000) #total time
event = random.randint(1,100) #randomize an event but make sure event < n
time_period = random.randint(0,n )
_lamda = (event/n)*time_period
k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

print ("The randomized Lambda = %f, n is randomized = %d, randomized number of event = %d" % (_lamda,n,event ))

time.sleep (1.5)

x_sum = []

#THE POISSON in the iterated loop
#IS iterated with i as time period changes as we run thorugh the simulation

for i in range(1,n):
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)
    x_sum.append(poisson)
    

plt.plot(x ,x_sum, color = 'r')
plt.show()
# Out:
# The randomized Lambda = 13.060138, n is randomized = 5371, randomized number of event = 81

# %% [markdown]
# Now we study for various.
#
# We will test
#
# 1. 0 < lambda < 1
# 2. 10 < lambda < 100
# 3. 200 < lambda < 1000
# 4. lambda --> infinity
# 5. lambda = 0
# 6. lambda < 0
#
# lambda < 0 is very unintuitive as we cannot have a negative time, time period and event.
# However we will still try to include to see if there are any results. However i predict there will be an error if not, a weird looking graph.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


#n = random.randint(1,150) #total time
#event = random.randint(0,30) #randomize an event but make sure event < n
n = 150
event = 20
_lamda = 0.0001

k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

print ("Lambda = %f, n is randomized = %d, event = %d. " % (_lamda,n,event ))

time.sleep (1.5)

x_sum = []

#counter = 0
#while _lamda > 1:
#    n = random.randint(0,200) #total time
#    event = random.randint(0,200)
#    _lamda = (event/n)
#    counter = counter + 1
#    k_events_in_time_period = random.randint(0,event)
#    time.sleep(1)
    
print ('')
print ("We regathered new random values and obtained Lambda = %f, n = %d, no. of events = %d. " % (_lamda,n,event ))

x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

for i in range(1,n):
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)

    x_sum.append(poisson)


plt.plot(x, x_sum, color ='b')
# Out:
# Lambda = 0.000100, n is randomized = 150, event = 20.
#
# We regathered new random values and obtained Lambda = 0.000100, n = 150, no. of events = 20.

# %% [markdown]
# # We notice that at _lamda = 0.0000001, the poisson distribution has an incomplete tail that decays after its maximum point.
#
# # Now we test _lamda = 0.1

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


#n = random.randint(1,150) #total time
#event = random.randint(0,30) #randomize an event but make sure event < n
n = 150
event = 20
_lamda = 0.1 

k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

print ("The Lambda is %f, n = %d, event = %d. " % (_lamda,n,event ))

time.sleep (1.5)

x_sum = []

#counter = 0
#while _lamda > 1:
#    n = random.randint(0,200) #total time
#    event = random.randint(0,200)
#    _lamda = (event/n)
#    counter = counter + 1
#    k_events_in_time_period = random.randint(0,event)
#    time.sleep(1)
    
#print ('')
#print ("We regathered new random values and obtained Lambda = %f, n = %d, no. of events = %d. " % (_lamda,n,event ))

x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

for i in range(1,n):
    
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)

    x_sum.append(poisson)


plt.plot(x, x_sum, color ='b')
# Out:
# The Lambda is 0.100000, n = 150, event = 20.

# %% [markdown]
# # At Lambda is 0.100000, we start to notice the fomulation of the poisson distribution curve.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


#n = random.randint(1,150) #total time
#event = random.randint(0,30) #randomize an event but make sure event < n
"""
Inititialisation of values
"""
n = 150
event = 20
_lamda = 0.99

k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

print ("The Lambda is %f, n = %d, event = %d. " % (_lamda,n,event ))

time.sleep (1.5)

x_sum = []

#counter = 0
#while _lamda > 1:
#    n = random.randint(0,200) #total time
#    event = random.randint(0,200)
#    _lamda = (event/n)
#    counter = counter + 1
#    k_events_in_time_period = random.randint(0,event)
#    time.sleep(1)
    
#print ('')
#print ("We regathered new random values and obtained Lambda = %f, n = %d, no. of events = %d. " % (_lamda,n,event ))

x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

for i in range(1,n):
    
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)

    x_sum.append(poisson)


plt.plot(x, x_sum, color ='b')
# Out:
# The Lambda is 0.990000, n = 150, event = 20.

# %% [markdown]
# # Close to 1, we get the peak leaning towards the right and its right most tail is missing.
#
# # Going to test at exactly _lamda = 1.0 we get

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


#n = random.randint(1,150) #total time
#event = random.randint(0,30) #randomize an event but make sure event < n
"""
Inititialisation of values
"""
n = 150
event = 20
_lamda = 1

k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

print ("Lambda is %f, n = %d, event = %d. " % (_lamda,n,event ))

time.sleep (1.5)

x_sum = []

x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

for i in range(1,n):
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)

    x_sum.append(poisson)


plt.plot(x, x_sum, color ='b')
# Out:
# The Lambda is 1.000000, n = 150, event = 20.

# %% [markdown]
# # The Poisson distribution has a better shape that when it is lesser than 1 however, does not show symmtery
#
# # Moving on we test 10 < lambda < 100 , and again now the graph shows an unusual exponential decay with a sharp edge.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


#n = random.randint(1,150) #total time
#event = random.randint(0,30) #randomize an event but make sure event < n
n = random.randint(1,10000) #total time
event = random.randint(1,100) #randomize an event but make sure event < n
time_period = random.randint(0,n )
_lamda = (event/n)*time_period
k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)


x_sum = []

counter = 0
while _lamda < 10 or _lamda > 100:
    n = random.randint(1,10000) #total time
    event = random.randint(0,100)
    time_period = random.randint(0,n)
    _lamda = (event/n)*time_period
    counter = counter + 1
    k_events_in_time_period = random.randint(0,event)
    
print ('')
print ("Lambda = %f, n = %d, no. of events = %d. " % (_lamda,n,event ))
x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

for i in range(1,n):
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)

    x_sum.append(poisson)


plt.plot(x, x_sum, color ='b')
# Out:
# Lambda = 14.173749, n = 6354, no. of events = 19.

# %% [markdown]
# # In this random simulation, the values pretty much is similar to that of _lamda = 1.0 and does not show anything too significance in difference.
#
# # NOw we test 200 < lambda < 1000
#
# # To reduce running time, i have manually set _lamda = 230 and notice the same trend occurs since _lamda = 1.0 but occasionally creates an exponential decay or a sigmoid function looking pattern

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


#n = random.randint(1,150) #total time
#event = random.randint(0,30) #randomize an event but make sure event < n
n = random.randint(1,10000) #total time
event = random.randint(1,20) #randomize an event but make sure event < n
time_period = random.randint(0,n )
_lamda = 230
k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

x_sum = []

counter = 0
while _lamda < 200 or _lamda > 1000:
    n = random.randint(1,10000) #total time
    event = random.randint(0,100)
    time_period = random.randint(0,n)
    _lamda = (event/n)*time_period
    counter = counter + 1
    k_events_in_time_period = random.randint(0,event)
    
print ('')
print ("Lambda = %f, n = %d, no. of events = %d. " % (_lamda,n,event ))
x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

for i in range(1,n):
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)

    x_sum.append(poisson)


plt.plot(x, x_sum, color ='b')
# Out:
# Lambda = 230.000000, n = 4495, no. of events = 13.
# 0

# %% [markdown]
# # Now we try lambda --> infinity
# # Again, no significant changes

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


#n = random.randint(1,150) #total time
#event = random.randint(0,30) #randomize an event but make sure event < n
n = random.randint(1,10000) #total time
event = random.randint(1,20) #randomize an event but make sure event < n
time_period = random.randint(0,n )
_lamda = 999999999999999999999999999999999999999999
k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

x_sum = []
    
print ('')
print ("Lambda = %f, n = %d, no. of events = %d. " % (_lamda,n,event ))
x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

for i in range(1,n):
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)

    x_sum.append(poisson)


plt.plot(x, x_sum, color ='b')
# Out:
# Lambda = 1000000000000000044885712678075916785549312.000000, n = 3710, no. of events = 3.

# %% [markdown]
# # NExt we test
#
# # lambda = 0

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


#n = random.randint(1,150) #total time
#event = random.randint(0,30) #randomize an event but make sure event < n
n = random.randint(1,10000) #total time
event = random.randint(1,20) #randomize an event but make sure event < n
time_period = random.randint(0,n )
_lamda = 0
k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

x_sum = []
    
print ('')
print ("Lambda = %f, n = %d, no. of events = %d. " % (_lamda,n,event ))
x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

for i in range(1,n):
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)

    x_sum.append(poisson)


plt.plot(x, x_sum, color ='b')
# Out:
# Lambda = 0.000000, n = 8998, no. of events = 2.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


#n = random.randint(1,150) #total time
#event = random.randint(0,30) #randomize an event but make sure event < n
n = random.randint(1,10000) #total time
event = random.randint(1,20) #randomize an event but make sure event < n
time_period = random.randint(0,n )
_lamda = 0
k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

x_sum = []
    
print ('')
print ("Lambda = %f, n = %d, no. of events = %d. " % (_lamda,n,event ))
x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

for i in range(1,n):
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)

    x_sum.append(poisson)


plt.plot(x, x_sum, color ='b')

# %% [markdown]
# # Again no visibile difference

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


#n = random.randint(1,150) #total time
#event = random.randint(0,30) #randomize an event but make sure event < n
n = random.randint(1,10000) #total time
event = random.randint(1,20) #randomize an event but make sure event < n
time_period = random.randint(0,n )
_lamda = -1
k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

x_sum = []
    
print ('')
print ("Lambda = %f, n = %d, no. of events = %d. " % (_lamda,n,event ))
x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

for i in range(1,n):
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)

    x_sum.append(poisson)


plt.plot(x, x_sum, color ='b')
# Out:
# Lambda = -1.000000, n = 7120, no. of events = 2.

# %% [markdown]
# # Now we test _lamda < 0.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math
import time


#n = random.randint(1,150) #total time
#event = random.randint(0,30) #randomize an event but make sure event < n
n = random.randint(1,10000) #total time
event = random.randint(1,20) #randomize an event but make sure event < n
time_period = random.randint(0,n )
_lamda = -100
k_events_in_time_period = random.randint(0,event)


x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

x_sum = []
    
print ('')
print ("Lambda = %f, n = %d, no. of events = %d. " % (_lamda,n,event ))
x = np.linspace(0,20,n-1)
r = np.random.uniform(0,1,n)

for i in range(1,n):
    poisson = np.exp(-1*((event/n)*i))*((((event/n)*i)**k_events_in_time_period))/math.factorial(k_events_in_time_period)

    x_sum.append(poisson)


plt.plot(x, x_sum, color ='b')
# Out:
# Lambda = -100.000000, n = 4360, no. of events = 5.

# %% [markdown]
# # Surprisingly, again, there is no change in the simulation. I normally use Spyder to keep executing the path and no visible change since we began _lamda = 1.0
